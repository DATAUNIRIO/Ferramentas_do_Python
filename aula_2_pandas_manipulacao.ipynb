# %% [markdown]
# # Revisão

# %%
x = 1

# %%
x+1
# Out:
# 2

# %% [markdown]
# Temos algumas palavras importantes pra lembrar!
#
# 1. São as "novas" de Python que tem a ver com orientação a objetos...
#
# Tudo no python é **objeto**, que é um sinônimo de **variável**, e isso quer dizer que o código vai se parecer com uma historinha sobre os objetos. Os objetos tomam algumas ações e essas ações são pré-determinadas numa lista e cada ação dessa lista se chama **método**

# %%
variavel_texto = "Fernando"

# %%
variavel_texto.

# %% [markdown]
# Também existem **funções** no pyhton, a `help` é um exemplo. Um **método** é mais ou menos como uma função, mas é uma função que mora um objeto específico. Já uma função como a `help` não mora em lugar nenhum.

# %%
help(variavel_texto.count)
# Out:
# Help on built-in function count:
#
# count(...) method of builtins.str instance
#     S.count(sub[, start[, end]]) -> int
#
#     Return the number of non-overlapping occurrences of substring sub in
#     string S[start:end].  Optional arguments start and end are
#     interpreted as in slice notation.

# %%
variavel_texto.upper()

upper(variavel_texto)
# Out:
# 'FERNANDO'

# %%
type(variavel_texto)
# Out:
# str

# %%
variavel_nova = "Fernando2"

help(str.capitalize)
# Out:
# Help on method_descriptor:
#
# capitalize(self, /)
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
import pandas

dados = pandas.read_csv("https://raw.githubusercontent.com/curso-r/main-r4ds-1/master/dados/imdb.csv")

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.sum()
# Out:
# 349301083041.0

# %%
lista = [5, 3, 4]

x = 1
y = 2
z = 3

lista_com_variaveis = [x, y, z]

lista_com_variaveis
# Out:
# [1, 2, 3]

# %%
lista_com_variaveis + lista
# Out:
# [1, 2, 3, 5, 3, 4]

# %% [markdown]
# ## Array do numpy

# %%
# %whos
# Out:
# Variable              Type         Data/Info
# --------------------------------------------
# dados                 DataFrame            id_filme         <...>[28490 rows x 20 columns]
# lista                 list         n=3
# lista_com_variaveis   list         n=3
# pandas                module       <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# variavel_nova         str          Fernando2
# variavel_texto        str          Fernando
# x                     int          2
# y                     int          2
# z                     int          3

# %%
import numpy

# %%
# %whos
# Out:
# Variable              Type         Data/Info
# --------------------------------------------
# dados                 DataFrame            id_filme         <...>[28490 rows x 20 columns]
# lista                 list         n=3
# lista_com_variaveis   list         n=3
# numpy                 module       <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# pandas                module       <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# variavel_nova         str          Fernando2
# variavel_texto        str          Fernando
# x                     int          2
# y                     int          2
# z                     int          3

# %%
array_numpy = numpy.array([1,2,3])

array_numpy_2 = numpy.array([5,3,4])

# %%
type(array_numpy)
# Out:
# numpy.ndarray

# %%
lista
# Out:
# [5, 3, 4]

# %%
array_numpy
# Out:
# array([1, 2, 3])

# %%
array_numpy_2
# Out:
# array([5, 3, 4])

# %%
array_numpy + array_numpy_2
# Out:
# array([6, 5, 7])

# %%
array_numpy/array_numpy_2
# Out:
# array([0.2       , 0.66666667, 0.75      ])

# %%
array_numpy**array_numpy_2
# Out:
# array([ 1,  8, 81])

# %%
array_numpy-array_numpy_2
# Out:
# array([-4, -1, -1])

# %%
numpy.array(["a", 1])
# Out:
# array(['a', '1'], dtype='<U21')

# %% [markdown]
# # Tipos básicos
#
# str (string)
# int (inteiro)
# num (numérico)
# object (meio que o "coringa" do pandas mas na maior parte das vezes quer dizer stringr)
#
# # Tipos básicos de array...
#
# métodos de array numérico
#
# # Tipos de misturas
#
# dict, tupla, lista

# %%
# Indo de lista pra array
array_numpy = numpy.array([1,2,3])

# Voltando de array pra lista
listona = list(array_numpy)

# %%
listona
# Out:
# [1, 2, 3]

# %%
vetor_de_tamanho_4 = numpy.array([3, 5, 7, 6])

# %%
vetor_de_tamanho_4 = numpy.array([3, 5, 7, 6])

vetor_de_tamanho_3 = numpy.array([1, 2, 3])


# isso dá erro:
vetor_de_tamanho_3 + vetor_de_tamanho_4

# enquanto no R, teríamos uma reciclagem

# vetor_de_tamanho_3 viraria [1, 2, 3, 1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-061f347db980> in <module>()
#       5
#       6 # isso dá erro:
# ----> 7 vetor_de_tamanho_3 + vetor_de_tamanho_4
#       8
#       9 # enquanto no R, teríamos uma reciclagem
#
# ValueError: operands could not be broadcast together with shapes (3,) (4,)

# %%
vetor_de_tamanho_4.mean()
# Out:
# 5.25

# %%
vetor_de_tamanho_4.min()
# Out:
# 3

# %%
vetor_de_tamanho_4.max()
# Out:
# 7

# %%
vetor_de_tamanho_4.std()
# Out:
# 1.479019945774904

# %%
vetor_de_tamanho_4.sort()

# %%
vetor_de_tamanho_4
# Out:
# array([3, 5, 6, 7])

# %%
numpy.log(vetor_de_tamanho_4)
# Out:
# array([1.09861229, 1.60943791, 1.79175947, 1.94591015])

# %%
numpy.mean(vetor_de_tamanho_4)
# Out:
# 5.25

# %%
# Exercícios

# 1. Crie um array utilizando o pacote numpy que contenha a idade das pessoas
# que moram com você ou que você convive de maneira mais próxima

array_idade_das_pessoas = numpy.array([90, 123, 23])

# 2. Calcule a média de idade das pessoas que estão no vetor anterior

array_idade_das_pessoas.mean()

array_idade_das_pessoas.sum()/len(array_idade_das_pessoas)

# 3. Explore os métodos de um ndarray do numpy para calcular a variância desse vetor de idades

array_idade_das_pessoas.var()
# Out:
# 1730.888888888889

# %%
numpy.array([1, "a"])

# str > float > int > bool
# Out:
# numpy.ndarray

# %%
numpy.array([1, 2]).astype("bool")
# Out:
# array([ True,  True])

# %%
array_de_numeros_em_texto = numpy.array(['1', '2'])

str(array_de_numeros_em_texto)
# Out:
# "['1' '2']"

# %%
type(array_de_numeros_em_texto)
# Out:
# numpy.ndarray

# %%
array_de_numeros_em_texto.dtype
# Out:
# dtype('<U1')

# %% [markdown]
# Pandas x Numpy
#
# Numpy é uma biblioteca/pacote/library que serve pra você fazer contas com vetores, métodos matemáticos
#
# o Pandas é uma biblioteca de manipulação de dados, então ela define o DataFrame e um milhão de métodos pra mexer com dataframe, tipo filtrar, criar coluna, sumarizar, pivotar etc. o Pandas depende do numpy
#
# o statsModels é a biblioteca de estatística do Python

# %% [markdown]
# ## Introdução ao Pandas

# %%
# %whos
# Out:
# Variable                    Type         Data/Info
# --------------------------------------------------
# arra_numpy_2                ndarray      3: 3 elems, type `int64`, 24 bytes
# array_de_numeros_em_texto   ndarray      2: 2 elems, type `<U1`, 8 bytes
# array_idade_das_pessoas     ndarray      3: 3 elems, type `int64`, 24 bytes
# array_numpy                 ndarray      3: 3 elems, type `int64`, 24 bytes
# array_numpy_2               ndarray      3: 3 elems, type `int64`, 24 bytes
# dados                       DataFrame            id_filme         <...>[28490 rows x 20 columns]
# lista                       list         n=3
# lista_com_variaveis         list         n=3
# listona                     list         n=3
# numpy                       module       <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# pandas                      module       <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# variavel_nova               str          Fernando2
# variavel_texto              str          Fernando
# vetor_de_tamanho_3          ndarray      3: 3 elems, type `int64`, 24 bytes
# vetor_de_tamanho_4          ndarray      4: 4 elems, type `int64`, 32 bytes
# x                           int          2
# y                           int          2
# z                           int          3

# %%
import pandas as pd

# %%
# %whos
# Out:
# Variable                    Type         Data/Info
# --------------------------------------------------
# arra_numpy_2                ndarray      3: 3 elems, type `int64`, 24 bytes
# array_de_numeros_em_texto   ndarray      2: 2 elems, type `<U1`, 8 bytes
# array_idade_das_pessoas     ndarray      3: 3 elems, type `int64`, 24 bytes
# array_numpy                 ndarray      3: 3 elems, type `int64`, 24 bytes
# array_numpy_2               ndarray      3: 3 elems, type `int64`, 24 bytes
# dados                       DataFrame            id_filme         <...>[28490 rows x 20 columns]
# lista                       list         n=3
# lista_com_variaveis         list         n=3
# listona                     list         n=3
# numpy                       module       <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# pandas                      module       <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# pd                          module       <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# variavel_nova               str          Fernando2
# variavel_texto              str          Fernando
# vetor_de_tamanho_3          ndarray      3: 3 elems, type `int64`, 24 bytes
# vetor_de_tamanho_4          ndarray      4: 4 elems, type `int64`, 32 bytes
# x                           int          2
# y                           int          2
# z                           int          3

# %%
imdb = pd.read_csv("https://raw.githubusercontent.com/curso-r/main-r4ds-1/master/dados/imdb.csv")

# %%
# %whos
# Out:
# Variable                    Type         Data/Info
# --------------------------------------------------
# arra_numpy_2                ndarray      3: 3 elems, type `int64`, 24 bytes
# array_de_numeros_em_texto   ndarray      2: 2 elems, type `<U1`, 8 bytes
# array_idade_das_pessoas     ndarray      3: 3 elems, type `int64`, 24 bytes
# array_numpy                 ndarray      3: 3 elems, type `int64`, 24 bytes
# array_numpy_2               ndarray      3: 3 elems, type `int64`, 24 bytes
# dados                       DataFrame            id_filme         <...>[28490 rows x 20 columns]
# imdb                        DataFrame            id_filme         <...>[28490 rows x 20 columns]
# lista                       list         n=3
# lista_com_variaveis         list         n=3
# listona                     list         n=3
# numpy                       module       <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# pandas                      module       <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# pd                          module       <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# variavel_nova               str          Fernando2
# variavel_texto              str          Fernando
# vetor_de_tamanho_3          ndarray      3: 3 elems, type `int64`, 24 bytes
# vetor_de_tamanho_4          ndarray      4: 4 elems, type `int64`, 32 bytes
# x                           int          2
# y                           int          2
# z                           int          3

# %%
type(imdb)
# Out:
# pandas.core.frame.DataFrame

# %%
numpy.array([1, 2, 0])/0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
# array([inf, inf, nan])

# %%
imdb
# Out:
#         id_filme                     titulo     ano data_lancamento  \
# 0      tt0023352                   Prestige  1931.0      1932-01-22
# 1      tt0037946                   Nob Hill  1945.0      1945-11-15
# 2      tt0216204                  The Shade  1999.0      2000-03-01
# 3      tt0171889  Viewer Discretion Advised  1998.0      2012-05-01
# 4      tt0092699             Broadcast News  1987.0      1988-04-01
# ...          ...                        ...     ...             ...
# 28485  tt7975244    Jumanji: The Next Level  2019.0      2019-12-25
# 28486  tt0051948      Monster on the Campus  1958.0      1958-12-17
# 28487  tt1369706                   The Ward  2010.0      2011-04-01
# 28488  tt0038549            A Game of Death  1945.0      1946-06-07
# 28489  tt0283026                    Swimfan  2002.0      2003-05-30
#
#                          generos  duracao pais  \
# 0               Adventure, Drama       71  USA
# 1                 Drama, Musical       95  USA
# 2                          Drama       83  USA
# 3                 Comedy, Horror      105  USA
# 4         Comedy, Drama, Romance      133  USA
# ...                          ...      ...  ...
# 28485  Action, Adventure, Comedy      123  USA
# 28486             Horror, Sci-Fi       77  USA
# 28487  Horror, Mystery, Thriller       89  USA
# 28488                  Adventure       72  USA
# 28489            Drama, Thriller       85  USA
#
#                                  idioma    orcamento      receita  \
# 0                               English          NaN          NaN
# 1                               English          NaN          NaN
# 2                               English     400000.0          NaN
# 3                               English          NaN          NaN
# 4      English, Spanish, French, German   20000000.0   67331309.0
# ...                                 ...          ...          ...
# 28485                           English  125000000.0  796575993.0
# 28486                           English          NaN          NaN
# 28487                           English   10000000.0    5343820.0
# 28488                           English          NaN          NaN
# 28489                           English   10000000.0   34411240.0
#
#        receita_eua  nota_imdb  num_avaliacoes                         direcao  \
# 0              NaN        5.7             240                     Tay Garnett
# 1              NaN        6.3             246                  Henry Hathaway
# 2              NaN        7.1             102                 Raphaël Nadjari
# 3              NaN        3.4             111  Eddie Beverly Jr., Tommy Blaze
# 4       51249404.0        7.2           26257                 James L. Brooks
# ...            ...        ...             ...                             ...
# 28485  316831246.0        6.7          168698                     Jake Kasdan
# 28486          NaN        5.8            1517                     Jack Arnold
# 28487          NaN        5.6           39789                  John Carpenter
# 28488          NaN        5.8             302                     Robert Wise
# 28489   28564995.0        5.1           18771                     John Polson
#
#                                   roteiro  \
# 0               Harry Hervey, Tay Garnett
# 1      Wanda Tuchock, Norman Reilly Raine
# 2      Fyodor Dostoevsky, Raphaël Nadjari
# 3              Tommy Blaze, Philip Morton
# 4                         James L. Brooks
# ...                                   ...
# 28485           Jake Kasdan, Jeff Pinkner
# 28486                        David Duncan
# 28487  Michael Rasmussen, Shawn Rasmussen
# 28488     Richard Connell, Norman Houston
# 28489  Charles F. Bohl, Phillip Schneider
#
#                                     producao  \
# 0                         RKO Pathé Pictures
# 1                      Twentieth Century Fox
# 2                                   Filmaker
# 3                        Troma Entertainment
# 4                             Amercent Films
# ...                                      ...
# 28485               Matt Tolmach Productions
# 28486  Universal International Pictures (UI)
# 28487               FilmNation Entertainment
# 28488                     RKO Radio Pictures
# 28489                  Twentieth Century Fox
#
#                                                   elenco  \
# 0      Ann Harding, Adolphe Menjou, Melvyn Douglas, I...
# 1      George Raft, Joan Bennett, Vivian Blaine, Pegg...
# 2      Richard Edson, Lorie Marino, Jeff Ware, Barbar...
# 3      Ken Donovan, Philip Morton, Caroline Jett, Tom...
# 4      William Hurt, Albert Brooks, Holly Hunter, Rob...
# ...                                                  ...
# 28485  Dwayne Johnson, Kevin Hart, Jack Black, Karen ...
# 28486  Arthur Franz, Joanna Moore, Judson Pratt, Nanc...
# 28487  Amber Heard, Mamie Gummer, Danielle Panabaker,...
# 28488  John Loder, Audrey Long, Edgar Barrier, Russel...
# 28489  Jesse Bradford, Erika Christensen, Shiri Apple...
#
#                                                descricao  \
# 0      A woman travels to a French penal colony in In...
# 1      The owner of a San Francisco saloon yearns to ...
# 2                                                    NaN
# 3      Ted Smith becomes trapped in the TV shows he w...
# 4      Take two rival television reporters: one hands...
# ...                                                  ...
# 28485  In Jumanji: The Next Level, the gang is back b...
# 28486  The blood of a primitive fish exposed to gamma...
# 28487  An institutionalized young woman becomes terro...
# 28488  A remake of Richard Connell's famous short sto...
# 28489  A high school senior with a promising swimming...
#
#        num_criticas_publico  num_criticas_critica
# 0                      12.0                   2.0
# 1                      11.0                   2.0
# 2                       1.0                   1.0
# 3                       5.0                   3.0
# 4                     142.0                  62.0
# ...                     ...                   ...
# 28485                 940.0                 241.0
# 28486                  49.0                  38.0
# 28487                 190.0                 263.0
# 28488                  11.0                  10.0
# 28489                 216.0                  88.0
#
# [28490 rows x 20 columns]

# %%
imdb.describe()
# Out:
#                 ano       duracao     orcamento       receita   receita_eua  \
# count  28489.000000  28490.000000  1.047000e+04  7.698000e+03  7.556000e+03
# mean    1985.658605     93.054826  1.213561e+07  4.537556e+07  2.518781e+07
# std       28.972694     18.578874  2.678579e+07  1.319881e+08  5.516075e+07
# min     1894.000000     42.000000  0.000000e+00  1.600000e+01  3.000000e+01
# 25%     1959.000000     84.000000  4.500000e+05  1.194390e+05  1.945568e+05
# 50%     1996.000000     91.000000  2.000000e+06  4.250656e+06  4.599253e+06
# 75%     2011.000000    100.000000  1.150000e+07  3.180537e+07  2.641456e+07
# max     2020.000000    398.000000  3.560000e+08  2.797801e+09  9.366622e+08
#
#           nota_imdb  num_avaliacoes  num_criticas_publico  \
# count  28490.000000    2.849000e+04          28186.000000
# mean       5.556279    1.451079e+04             62.611509
# std        1.284463    6.855500e+04            202.058141
# min        1.100000    9.900000e+01              1.000000
# 25%        4.800000    2.300000e+02              8.000000
# 50%        5.800000    6.060000e+02             17.000000
# 75%        6.500000    2.893750e+03             43.000000
# max        9.700000    2.278845e+06           8869.000000
#
#        num_criticas_critica
# count          26618.000000
# mean              32.225900
# std               63.233244
# min                1.000000
# 25%                4.000000
# 50%               10.000000
# 75%               30.000000
# max              909.000000

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28490 entries, 0 to 28489
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_filme              28490 non-null  object
#  1   titulo                28490 non-null  object
#  2   ano                   28489 non-null  float64
#  3   data_lancamento       28490 non-null  object
#  4   generos               28490 non-null  object
#  5   duracao               28490 non-null  int64
#  6   pais                  28490 non-null  object
#  7   idioma                28146 non-null  object
#  8   orcamento             10470 non-null  float64
#  9   receita               7698 non-null   float64
#  10  receita_eua           7556 non-null   float64
#  11  nota_imdb             28490 non-null  float64
#  12  num_avaliacoes        28490 non-null  int64
#  13  direcao               28457 non-null  object
#  14  roteiro               28289 non-null  object
#  15  producao              27332 non-null  object
#  16  elenco                28464 non-null  object
#  17  descricao             28418 non-null  object
#  18  num_criticas_publico  28186 non-null  float64
#  19  num_criticas_critica  26618 non-null  float64
# dtypes: float64(7), int64(2), object(11)
# memory usage: 4.3+ MB

# %% [markdown]
# # Principais verbos de manipualação de dados no Pandas
#
# - Ordenar linhas (sort_values)
# - Selecionar linhas/colunas
#     - Selecionar colunas = "filter" do Python x "select" do R
#     - Selecionar linhas = "query" do Python x "filter" do R
# - Criar colunas
# - Sumarizar (com ou sem grupos)
# - Pivotar

# %%
# no dplyr R a gente faz arrange(imdb, ano)

# no Python Pandas:

dados.sort_values(["ano", "titulo"], ascending = [False, True])

colunas_para_ordenar = ["receita"]

dados_ordenados = dados.sort_values(colunas_para_ordenar, ascending = True)
# não tem modificação IN PLACE acontecendo

dados_ordenados
# Out:
#          id_filme                     titulo     ano data_lancamento  \
# 17890   tt0041452                The Heiress  1949.0      1950-11-23
# 12305   tt0429277                  Zyzzyx Rd  2006.0      2006-02-24
# 26861   tt0932669         Older Than America  2008.0      2012-02-09
# 24303   tt0066542  A Walk in the Spring Rain  1970.0            1970
# 3341    tt3774790                   400 Days  2015.0      2016-01-15
# ...           ...                        ...     ...             ...
# 28482   tt1308745                 The Absent  2011.0      2011-01-07
# 28483  tt10253466                    Badland  2019.0      2019-11-01
# 28484   tt0041687         Neptune's Daughter  1949.0            1951
# 28486   tt0051948      Monster on the Campus  1958.0      1958-12-17
# 28488   tt0038549            A Game of Death  1945.0      1946-06-07
#
#                          generos  duracao pais            idioma  orcamento  \
# 17890             Drama, Romance      115  USA   English, French  2600000.0
# 12305     Crime, Drama, Thriller       90  USA           English  2000000.0
# 26861                      Drama      102  USA           English  1000000.0
# 24303             Drama, Romance       98  USA           English        NaN
# 3341   Mystery, Sci-Fi, Thriller       91  USA           English        NaN
# ...                          ...      ...  ...               ...        ...
# 28482           Horror, Thriller       81  USA  English, Spanish        NaN
# 28483                    Western      117  USA           English        NaN
# 28484   Comedy, Musical, Romance       95  USA           English        NaN
# 28486             Horror, Sci-Fi       77  USA           English        NaN
# 28488                  Adventure       72  USA           English        NaN
#
#        receita  receita_eua  nota_imdb  num_avaliacoes             direcao  \
# 17890     16.0          NaN        8.1           13301       William Wyler
# 12305     30.0         30.0        4.1             983         John Penney
# 26861     32.0          NaN        5.3             857  Georgina Lightning
# 24303     52.0          NaN        6.1             647           Guy Green
# 3341      58.0          NaN        4.4           10018       Matt Osterman
# ...        ...          ...        ...             ...                 ...
# 28482      NaN          NaN        3.5             132        Sage Bannick
# 28483      NaN          NaN        5.5            1693          Justin Lee
# 28484      NaN          NaN        6.5            1299      Edward Buzzell
# 28486      NaN          NaN        5.8            1517         Jack Arnold
# 28488      NaN          NaN        5.8             302         Robert Wise
#
#                                        roteiro  \
# 17890               Ruth Goetz, Augustus Goetz
# 12305                              John Penney
# 26861  Georgina Lightning, Christine K. Walker
# 24303       Rachel Maddux, Stirling Silliphant
# 3341                             Matt Osterman
# ...                                        ...
# 28482             Damon Abdallah, Sage Bannick
# 28483                               Justin Lee
# 28484             Dorothy Kingsley, Ray Singer
# 28486                             David Duncan
# 28488          Richard Connell, Norman Houston
#
#                                     producao  \
# 17890                     Paramount Pictures
# 12305                             Zyzzyx LLC
# 26861                     Older Than America
# 24303                      Columbia Pictures
# 3341                           Content Media
# ...                                      ...
# 28482                             Last Night
# 28483               Papa Octopus Productions
# 28484              Metro-Goldwyn-Mayer (MGM)
# 28486  Universal International Pictures (UI)
# 28488                     RKO Radio Pictures
#
#                                                   elenco  \
# 17890  Olivia de Havilland, Montgomery Clift, Ralph R...
# 12305  Leo Grillo, Katherine Heigl, Tom Sizemore, Ric...
# 26861  Adam Beach, Tantoo Cardinal, Bradley Cooper, G...
# 24303  Anthony Quinn, Ingrid Bergman, Fritz Weaver, K...
# 3341   Brandon Routh, Dane Cook, Caity Lotz, Ben Feld...
# ...                                                  ...
# 28482  Bryan Kirkwood, Vanessa Zima, Denny Kirkwood, ...
# 28483  Kevin Makely, Mira Sorvino, Bruce Dern, Wes St...
# 28484  Esther Williams, Red Skelton, Ricardo Montalba...
# 28486  Arthur Franz, Joanna Moore, Judson Pratt, Nanc...
# 28488  John Loder, Audrey Long, Edgar Barrier, Russel...
#
#                                                descricao  \
# 17890  A young naive woman falls for a handsome young...
# 12305  The family man accountant Grant travels to Las...
# 26861  A woman's haunting visions reveal a Catholic p...
# 24303  The Merediths move to an isolated farm. Mrs. M...
# 3341   With their 400-day mission simulation nearing ...
# ...                                                  ...
# 28482  A High School teacher falls for his prize stud...
# 28483  Detective Matthias Breecher is hired to track ...
# 28484  A swimsuit fashion designer is determined to p...
# 28486  The blood of a primitive fish exposed to gamma...
# 28488  A remake of Richard Connell's famous short sto...
#
#        num_criticas_publico  num_criticas_critica
# 17890                 140.0                  61.0
# 12305                  11.0                   2.0
# 26861                  24.0                   6.0
# 24303                  13.0                   4.0
# 3341                  143.0                  28.0
# ...                     ...                   ...
# 28482                   6.0                  13.0
# 28483                 110.0                   8.0
# 28484                  26.0                  20.0
# 28486                  49.0                  38.0
# 28488                  11.0                  10.0
#
# [28490 rows x 20 columns]

# %%
dados
# Out:
#         id_filme                     titulo     ano data_lancamento  \
# 0      tt0023352                   Prestige  1931.0      1932-01-22
# 1      tt0037946                   Nob Hill  1945.0      1945-11-15
# 2      tt0216204                  The Shade  1999.0      2000-03-01
# 3      tt0171889  Viewer Discretion Advised  1998.0      2012-05-01
# 4      tt0092699             Broadcast News  1987.0      1988-04-01
# ...          ...                        ...     ...             ...
# 28485  tt7975244    Jumanji: The Next Level  2019.0      2019-12-25
# 28486  tt0051948      Monster on the Campus  1958.0      1958-12-17
# 28487  tt1369706                   The Ward  2010.0      2011-04-01
# 28488  tt0038549            A Game of Death  1945.0      1946-06-07
# 28489  tt0283026                    Swimfan  2002.0      2003-05-30
#
#                          generos  duracao pais  \
# 0               Adventure, Drama       71  USA
# 1                 Drama, Musical       95  USA
# 2                          Drama       83  USA
# 3                 Comedy, Horror      105  USA
# 4         Comedy, Drama, Romance      133  USA
# ...                          ...      ...  ...
# 28485  Action, Adventure, Comedy      123  USA
# 28486             Horror, Sci-Fi       77  USA
# 28487  Horror, Mystery, Thriller       89  USA
# 28488                  Adventure       72  USA
# 28489            Drama, Thriller       85  USA
#
#                                  idioma    orcamento      receita  \
# 0                               English          NaN          NaN
# 1                               English          NaN          NaN
# 2                               English     400000.0          NaN
# 3                               English          NaN          NaN
# 4      English, Spanish, French, German   20000000.0   67331309.0
# ...                                 ...          ...          ...
# 28485                           English  125000000.0  796575993.0
# 28486                           English          NaN          NaN
# 28487                           English   10000000.0    5343820.0
# 28488                           English          NaN          NaN
# 28489                           English   10000000.0   34411240.0
#
#        receita_eua  nota_imdb  num_avaliacoes                         direcao  \
# 0              NaN        5.7             240                     Tay Garnett
# 1              NaN        6.3             246                  Henry Hathaway
# 2              NaN        7.1             102                 Raphaël Nadjari
# 3              NaN        3.4             111  Eddie Beverly Jr., Tommy Blaze
# 4       51249404.0        7.2           26257                 James L. Brooks
# ...            ...        ...             ...                             ...
# 28485  316831246.0        6.7          168698                     Jake Kasdan
# 28486          NaN        5.8            1517                     Jack Arnold
# 28487          NaN        5.6           39789                  John Carpenter
# 28488          NaN        5.8             302                     Robert Wise
# 28489   28564995.0        5.1           18771                     John Polson
#
#                                   roteiro  \
# 0               Harry Hervey, Tay Garnett
# 1      Wanda Tuchock, Norman Reilly Raine
# 2      Fyodor Dostoevsky, Raphaël Nadjari
# 3              Tommy Blaze, Philip Morton
# 4                         James L. Brooks
# ...                                   ...
# 28485           Jake Kasdan, Jeff Pinkner
# 28486                        David Duncan
# 28487  Michael Rasmussen, Shawn Rasmussen
# 28488     Richard Connell, Norman Houston
# 28489  Charles F. Bohl, Phillip Schneider
#
#                                     producao  \
# 0                         RKO Pathé Pictures
# 1                      Twentieth Century Fox
# 2                                   Filmaker
# 3                        Troma Entertainment
# 4                             Amercent Films
# ...                                      ...
# 28485               Matt Tolmach Productions
# 28486  Universal International Pictures (UI)
# 28487               FilmNation Entertainment
# 28488                     RKO Radio Pictures
# 28489                  Twentieth Century Fox
#
#                                                   elenco  \
# 0      Ann Harding, Adolphe Menjou, Melvyn Douglas, I...
# 1      George Raft, Joan Bennett, Vivian Blaine, Pegg...
# 2      Richard Edson, Lorie Marino, Jeff Ware, Barbar...
# 3      Ken Donovan, Philip Morton, Caroline Jett, Tom...
# 4      William Hurt, Albert Brooks, Holly Hunter, Rob...
# ...                                                  ...
# 28485  Dwayne Johnson, Kevin Hart, Jack Black, Karen ...
# 28486  Arthur Franz, Joanna Moore, Judson Pratt, Nanc...
# 28487  Amber Heard, Mamie Gummer, Danielle Panabaker,...
# 28488  John Loder, Audrey Long, Edgar Barrier, Russel...
# 28489  Jesse Bradford, Erika Christensen, Shiri Apple...
#
#                                                descricao  \
# 0      A woman travels to a French penal colony in In...
# 1      The owner of a San Francisco saloon yearns to ...
# 2                                                    NaN
# 3      Ted Smith becomes trapped in the TV shows he w...
# 4      Take two rival television reporters: one hands...
# ...                                                  ...
# 28485  In Jumanji: The Next Level, the gang is back b...
# 28486  The blood of a primitive fish exposed to gamma...
# 28487  An institutionalized young woman becomes terro...
# 28488  A remake of Richard Connell's famous short sto...
# 28489  A high school senior with a promising swimming...
#
#        num_criticas_publico  num_criticas_critica
# 0                      12.0                   2.0
# 1                      11.0                   2.0
# 2                       1.0                   1.0
# 3                       5.0                   3.0
# 4                     142.0                  62.0
# ...                     ...                   ...
# 28485                 940.0                 241.0
# 28486                  49.0                  38.0
# 28487                 190.0                 263.0
# 28488                  11.0                  10.0
# 28489                 216.0                  88.0
#
# [28490 rows x 20 columns]

# %% [markdown]
# # Selecionando colunas

# %%
imdb_apenas_ano_receita = imdb.filter(['ano', 'receita'])

imdb_apenas_ano_receita
# Out:
#           ano      receita
# 0      1931.0          NaN
# 1      1945.0          NaN
# 2      1999.0          NaN
# 3      1998.0          NaN
# 4      1987.0   67331309.0
# ...       ...          ...
# 28485  2019.0  796575993.0
# 28486  1958.0          NaN
# 28487  2010.0    5343820.0
# 28488  1945.0          NaN
# 28489  2002.0   34411240.0
#
# [28490 rows x 2 columns]

# %%
colunas_para_selecionar = ['ano', 'receita', 'orcamento']

apenas_ano_receita_orcamento = imdb.filter(colunas_para_selecionar).sort_values('receita')

ordenado_receita_selecao = (imdb.
                        filter(colunas_para_selecionar).
                        sort_values("receita")
)
# isso aqui é o que a gente chama de method chaining.
# CUIDADO!!!! PRECISA COMEÇAR COM PARÊNTESES

ordenado_receita_selecao = imdb.
filter(colunas_para_selecionar).
sort_values("receita")
# NÃO FUNCIONA!!

ordenado_receita_selecao = (imdb
.filter(colunas_para_selecionar)
.sort_values("receita"))
# funciona
# Out:
#   File "<ipython-input-158-60deaeb72c9c>", line 12
#     ordenado_receita_selecao = imdb.
#                                     ^
# SyntaxError: invalid syntax

# %%
imdb.loc[:, ["ano", "receita"]]

imdb.loc[:, colunas_para_selecionar]

imdb.filter(colunas_para_selecionar)
# Out:
#           ano      receita    orcamento
# 0      1931.0          NaN          NaN
# 1      1945.0          NaN          NaN
# 2      1999.0          NaN     400000.0
# 3      1998.0          NaN          NaN
# 4      1987.0   67331309.0   20000000.0
# ...       ...          ...          ...
# 28485  2019.0  796575993.0  125000000.0
# 28486  1958.0          NaN          NaN
# 28487  2010.0    5343820.0   10000000.0
# 28488  1945.0          NaN          NaN
# 28489  2002.0   34411240.0   10000000.0
#
# [28490 rows x 3 columns]

# %%
(imdb.
 query("ano <= 1945").
 filter(["ano", "titulo"]))

# select(filter(dados, ano <= 1945), ano, titulo)
# dados |> filter(ano <= 1934) é o mesmo que filter(dados, ano <= 1945) 

# operadores lógicos

# & significa E (podemos usar and em vários casos)
# | significa OU (podemos usar or em vários casos)
# == significa comparação
# != significa diferença

# > 
# <

# in (contenção)??? %in%
# PRÓXIMA AULA!!!

# podemos usar and ao invés de &
imdb.query("ano <= 1945 or orcamento > receita")

# pode o and e o or
# Out:
#         id_filme                             titulo     ano data_lancamento  \
# 0      tt0023352                           Prestige  1931.0      1932-01-22
# 1      tt0037946                           Nob Hill  1945.0      1945-11-15
# 5      tt0037931                    Murder, He Says  1945.0      1945-06-23
# 10     tt0032832            Mysterious Doctor Satan  1940.0      1940-12-13
# 13     tt0033945  Never Give a Sucker an Even Break  1941.0      1947-05-02
# ...          ...                                ...     ...             ...
# 28472  tt2611626                 Force of Execution  2013.0      2014-03-13
# 28477  tt0023556                               Taxi  1931.0      1932-01-23
# 28478  tt0022751                       Central Park  1932.0      1932-12-10
# 28487  tt1369706                           The Ward  2010.0      2011-04-01
# 28488  tt0038549                    A Game of Death  1945.0      1946-06-07
#
#                          generos  duracao pais            idioma   orcamento  \
# 0               Adventure, Drama       71  USA           English         NaN
# 1                 Drama, Musical       95  USA           English         NaN
# 5         Comedy, Crime, Mystery       91  USA           English         NaN
# 10      Adventure, Action, Crime      267  USA           English    147381.0
# 13               Comedy, Musical       71  USA           English         NaN
# ...                          ...      ...  ...               ...         ...
# 28472              Action, Crime       99  USA           English   8000000.0
# 28477      Crime, Drama, Romance       69  USA  English, Yiddish         NaN
# 28478      Crime, Drama, Romance       58  USA           English         NaN
# 28487  Horror, Mystery, Thriller       89  USA           English  10000000.0
# 28488                  Adventure       72  USA           English         NaN
#
#          receita  receita_eua  nota_imdb  num_avaliacoes  \
# 0            NaN          NaN        5.7             240
# 1            NaN          NaN        6.3             246
# 5            NaN          NaN        7.1            1639
# 10           NaN          NaN        7.0             201
# 13           NaN          NaN        7.2            2108
# ...          ...          ...        ...             ...
# 28472    87122.0          NaN        4.4            2941
# 28477        NaN          NaN        6.7            1158
# 28478        NaN          NaN        6.1             332
# 28487  5343820.0          NaN        5.6           39789
# 28488        NaN          NaN        5.8             302
#
#                             direcao                             roteiro  \
# 0                       Tay Garnett           Harry Hervey, Tay Garnett
# 1                    Henry Hathaway  Wanda Tuchock, Norman Reilly Raine
# 5                   George Marshall           Lou Breslow, Jack Moffitt
# 10     John English, William Witney    Franklin Adreon, Ronald Davidson
# 13                  Edward F. Cline   John T. Neville, Prescott Chaplin
# ...                             ...                                 ...
# 28472                  Keoni Waxman      Richard Beattie, Michael Black
# 28477                  Roy Del Ruth     Kenyon Nicholson, Kubec Glasmon
# 28478                John G. Adolfi        Ward Morehouse, Earl Baldwin
# 28487                John Carpenter  Michael Rasmussen, Shawn Rasmussen
# 28488                   Robert Wise     Richard Connell, Norman Houston
#
#                                 producao  \
# 0                     RKO Pathé Pictures
# 1                  Twentieth Century Fox
# 5                     Paramount Pictures
# 10     Republic Pictures Corporation (I)
# 13                    Universal Pictures
# ...                                  ...
# 28472                   Voltage Pictures
# 28477                       Warner Bros.
# 28478            First National Pictures
# 28487           FilmNation Entertainment
# 28488                 RKO Radio Pictures
#
#                                                   elenco  \
# 0      Ann Harding, Adolphe Menjou, Melvyn Douglas, I...
# 1      George Raft, Joan Bennett, Vivian Blaine, Pegg...
# 5      Fred MacMurray, Helen Walker, Marjorie Main, J...
# 10     Eduardo Ciannelli, Robert Wilcox, William Newe...
# 13     W.C. Fields, Gloria Jean, Leon Errol, Billy Le...
# ...                                                  ...
# 28472  Steven Seagal, Ving Rhames, Danny Trejo, Bren ...
# 28477  James Cagney, Loretta Young, George E. Stone, ...
# 28478  Joan Blondell, Wallace Ford, Guy Kibbee, Henry...
# 28487  Amber Heard, Mamie Gummer, Danielle Panabaker,...
# 28488  John Loder, Audrey Long, Edgar Barrier, Russel...
#
#                                                descricao  \
# 0      A woman travels to a French penal colony in In...
# 1      The owner of a San Francisco saloon yearns to ...
# 5      A pollster stumbles on a family of murderous h...
# 10     A mad scientist plots the domination of Americ...
# 13     A filmmaker attempts to sell a surreal script ...
# ...                                                  ...
# 28472  A crime boss sends his top man to kill a priso...
# 28477  Independent cab drivers struggling against a t...
# 28478  Gangsters posing as police officers offer a wo...
# 28487  An institutionalized young woman becomes terro...
# 28488  A remake of Richard Connell's famous short sto...
#
#        num_criticas_publico  num_criticas_critica
# 0                      12.0                   2.0
# 1                      11.0                   2.0
# 5                      35.0                  10.0
# 10                      4.0                   7.0
# 13                     35.0                  18.0
# ...                     ...                   ...
# 28472                  35.0                  34.0
# 28477                  33.0                  15.0
# 28478                  16.0                   1.0
# 28487                 190.0                 263.0
# 28488                  11.0                  10.0
#
# [6273 rows x 20 columns]

# %%
# o fato disso: imdb.ano <= 1945 resultar em True/False

# garante que

imdb.query("ano <= 1945")
# Out:
#         id_filme                             titulo     ano data_lancamento  \
# 0      tt0023352                           Prestige  1931.0      1932-01-22
# 1      tt0037946                           Nob Hill  1945.0      1945-11-15
# 5      tt0037931                    Murder, He Says  1945.0      1945-06-23
# 10     tt0032832            Mysterious Doctor Satan  1940.0      1940-12-13
# 13     tt0033945  Never Give a Sucker an Even Break  1941.0      1947-05-02
# ...          ...                                ...     ...             ...
# 28452  tt0035573                    A Yank in Libya  1942.0      1942-07-24
# 28457  tt0026120              The Bishop Misbehaves  1935.0      1935-09-13
# 28477  tt0023556                               Taxi  1931.0      1932-01-23
# 28478  tt0022751                       Central Park  1932.0      1932-12-10
# 28488  tt0038549                    A Game of Death  1945.0      1946-06-07
#
#                         generos  duracao pais            idioma  orcamento  \
# 0              Adventure, Drama       71  USA           English        NaN
# 1                Drama, Musical       95  USA           English        NaN
# 5        Comedy, Crime, Mystery       91  USA           English        NaN
# 10     Adventure, Action, Crime      267  USA           English   147381.0
# 13              Comedy, Musical       71  USA           English        NaN
# ...                         ...      ...  ...               ...        ...
# 28452       Drama, Romance, War       67  USA           English        NaN
# 28457             Comedy, Crime       85  USA           English        NaN
# 28477     Crime, Drama, Romance       69  USA  English, Yiddish        NaN
# 28478     Crime, Drama, Romance       58  USA           English        NaN
# 28488                 Adventure       72  USA           English        NaN
#
#        receita  receita_eua  nota_imdb  num_avaliacoes  \
# 0          NaN          NaN        5.7             240
# 1          NaN          NaN        6.3             246
# 5          NaN          NaN        7.1            1639
# 10         NaN          NaN        7.0             201
# 13         NaN          NaN        7.2            2108
# ...        ...          ...        ...             ...
# 28452      NaN          NaN        4.4             164
# 28457      NaN          NaN        6.6             224
# 28477      NaN          NaN        6.7            1158
# 28478      NaN          NaN        6.1             332
# 28488      NaN          NaN        5.8             302
#
#                             direcao                             roteiro  \
# 0                       Tay Garnett           Harry Hervey, Tay Garnett
# 1                    Henry Hathaway  Wanda Tuchock, Norman Reilly Raine
# 5                   George Marshall           Lou Breslow, Jack Moffitt
# 10     John English, William Witney    Franklin Adreon, Ronald Davidson
# 13                  Edward F. Cline   John T. Neville, Prescott Chaplin
# ...                             ...                                 ...
# 28452                 Albert Herman  Arthur St. Claire, Sherman L. Lowe
# 28457            Ewald André Dupont   Leon Gordon, Frederick J. Jackson
# 28477                  Roy Del Ruth     Kenyon Nicholson, Kubec Glasmon
# 28478                John G. Adolfi        Ward Morehouse, Earl Baldwin
# 28488                   Robert Wise     Richard Connell, Norman Houston
#
#                                 producao  \
# 0                     RKO Pathé Pictures
# 1                  Twentieth Century Fox
# 5                     Paramount Pictures
# 10     Republic Pictures Corporation (I)
# 13                    Universal Pictures
# ...                                  ...
# 28452                  M & H Productions
# 28457          Metro-Goldwyn-Mayer (MGM)
# 28477                       Warner Bros.
# 28478            First National Pictures
# 28488                 RKO Radio Pictures
#
#                                                   elenco  \
# 0      Ann Harding, Adolphe Menjou, Melvyn Douglas, I...
# 1      George Raft, Joan Bennett, Vivian Blaine, Pegg...
# 5      Fred MacMurray, Helen Walker, Marjorie Main, J...
# 10     Eduardo Ciannelli, Robert Wilcox, William Newe...
# 13     W.C. Fields, Gloria Jean, Leon Errol, Billy Le...
# ...                                                  ...
# 28452  Walter Woolf King, Joan Woodbury, H.B. Warner,...
# 28457  Edmund Gwenn, Maureen O'Sullivan, Lucile Watso...
# 28477  James Cagney, Loretta Young, George E. Stone, ...
# 28478  Joan Blondell, Wallace Ford, Guy Kibbee, Henry...
# 28488  John Loder, Audrey Long, Edgar Barrier, Russel...
#
#                                                descricao  \
# 0      A woman travels to a French penal colony in In...
# 1      The owner of a San Francisco saloon yearns to ...
# 5      A pollster stumbles on a family of murderous h...
# 10     A mad scientist plots the domination of Americ...
# 13     A filmmaker attempts to sell a surreal script ...
# ...                                                  ...
# 28452  American correspondent Mike Malone uncovers a ...
# 28457  On a walking tour of English cathedrals, Donal...
# 28477  Independent cab drivers struggling against a t...
# 28478  Gangsters posing as police officers offer a wo...
# 28488  A remake of Richard Connell's famous short sto...
#
#        num_criticas_publico  num_criticas_critica
# 0                      12.0                   2.0
# 1                      11.0                   2.0
# 5                      35.0                  10.0
# 10                      4.0                   7.0
# 13                     35.0                  18.0
# ...                     ...                   ...
# 28452                  10.0                   2.0
# 28457                   7.0                   1.0
# 28477                  33.0                  15.0
# 28478                  16.0                   1.0
# 28488                  11.0                  10.0
#
# [4170 rows x 20 columns]

# %%
filmes_que_deram_lucro = imdb.query("receita > orcamento")

# isso aqui dá True/False....
filmes_que_deram_lucro.receita.isna()

# Será que posso colocar no "query"???

imdb.query("receita.isnan()")
# não podemos...

# %%
# o que será que o comando abaixo faz com os NaN???
filmes_que_deram_lucro = imdb.query("receita > orcamento")

# Podemos testar ordenando:
filmes_que_deram_lucro.sort_values("receita")

# Os NaN foram embora!

# %%
imdb.query("receita/orcamento > 1")
# Out:
#         id_filme                        titulo     ano data_lancamento  \
# 4      tt0092699                Broadcast News  1987.0      1988-04-01
# 11     tt0183505            Me, Myself & Irene  2000.0      2000-09-08
# 21     tt0093640                    No Way Out  1987.0      1987-12-11
# 22     tt0494652  Welcome Home, Roscoe Jenkins  2008.0      2008-02-08
# 25     tt0285869                 Pandora's Box  2002.0      2002-09-27
# ...          ...                           ...     ...             ...
# 28435  tt0119215                   Good Burger  1997.0      1997-07-25
# 28455  tt0075223                 Silver Streak  1976.0      1977-04-23
# 28480  tt1706593                     Chronicle  2012.0      2012-05-09
# 28485  tt7975244       Jumanji: The Next Level  2019.0      2019-12-25
# 28489  tt0283026                       Swimfan  2002.0      2003-05-30
#
#                          generos  duracao pais  \
# 4         Comedy, Drama, Romance      133  USA
# 11                        Comedy      116  USA
# 21          Action, Crime, Drama      114  USA
# 22               Comedy, Romance      104  USA
# 25               Drama, Thriller      103  USA
# ...                          ...      ...  ...
# 28435             Comedy, Family       95  USA
# 28455      Action, Comedy, Crime      114  USA
# 28480    Drama, Sci-Fi, Thriller       89  USA
# 28485  Action, Adventure, Comedy      123  USA
# 28489            Drama, Thriller       85  USA
#
#                                  idioma    orcamento      receita  \
# 4      English, Spanish, French, German   20000000.0   67331309.0
# 11                      English, German   51000000.0  149270999.0
# 21                     English, Russian   15000000.0   35509515.0
# 22                              English   35000000.0   43655418.0
# 25                              English     800000.0     881950.0
# ...                                 ...          ...          ...
# 28435                           English    9000000.0   23712993.0
# 28455                           English    6500000.0   51079064.0
# 28480                           English   12000000.0  126636097.0
# 28485                           English  125000000.0  796575993.0
# 28489                           English   10000000.0   34411240.0
#
#        receita_eua  nota_imdb  num_avaliacoes                         direcao  \
# 4       51249404.0        7.2           26257                 James L. Brooks
# 11      90570999.0        6.6          219069  Bobby Farrelly, Peter Farrelly
# 21      35509515.0        7.1           34513                 Roger Donaldson
# 22      42436517.0        5.5           13315                  Malcolm D. Lee
# 25        881950.0        4.9             629                       Rob Hardy
# ...            ...        ...             ...                             ...
# 28435   23712993.0        5.7           25675                   Brian Robbins
# 28455   51079064.0        6.9           17442                   Arthur Hiller
# 28480   64575175.0        7.0          237285                      Josh Trank
# 28485  316831246.0        6.7          168698                     Jake Kasdan
# 28489   28564995.0        5.1           18771                     John Polson
#
#                                               roteiro  \
# 4                                     James L. Brooks
# 11                       Peter Farrelly, Mike Cerrone
# 21                    Kenneth Fearing, Robert Garland
# 22                                     Malcolm D. Lee
# 25     Gregory Ramon Anderson, Gregory Ramon Anderson
# ...                                               ...
# 28435                    Dan Schneider, Kevin Kopelow
# 28455                                   Colin Higgins
# 28480                          Max Landis, Max Landis
# 28485                       Jake Kasdan, Jeff Pinkner
# 28489              Charles F. Bohl, Phillip Schneider
#
#                           producao  \
# 4                   Amercent Films
# 11           Twentieth Century Fox
# 21                  Orion Pictures
# 22              Universal Pictures
# 25                Rainforest Films
# ...                            ...
# 28435           Paramount Pictures
# 28455  Frank Yablans Presentations
# 28480        Twentieth Century Fox
# 28485     Matt Tolmach Productions
# 28489        Twentieth Century Fox
#
#                                                   elenco  \
# 4      William Hurt, Albert Brooks, Holly Hunter, Rob...
# 11     Jim Carrey, Renée Zellweger, Anthony Anderson,...
# 21     Kevin Costner, Gene Hackman, Sean Young, Will ...
# 22     Martin Lawrence, James Earl Jones, Margaret Av...
# 25     Chrystale Wilson, Tyson Beckford, Joey Lawrenc...
# ...                                                  ...
# 28435  Kel Mitchell, Kenan Thompson, Sinbad, Abe Vigo...
# 28455  Gene Wilder, Jill Clayburgh, Richard Pryor, Pa...
# 28480  Dane DeHaan, Alex Russell, Michael B. Jordan, ...
# 28485  Dwayne Johnson, Kevin Hart, Jack Black, Karen ...
# 28489  Jesse Bradford, Erika Christensen, Shiri Apple...
#
#                                                descricao  \
# 4      Take two rival television reporters: one hands...
# 11     A nice-guy cop with Dissociative Identity Diso...
# 21     A coverup and witchhunt occur after a politici...
# 22     Dr. RJ Stevens is a talk show host who visits ...
# 25     Mia DuBois (Calhoun) is a walking cliché--a su...
# ...                                                  ...
# 28435  Two dim-witted teenagers are forced to save th...
# 28455  On a long-distance train trip, a man finds rom...
# 28480  Three high school friends gain superpowers aft...
# 28485  In Jumanji: The Next Level, the gang is back b...
# 28489  A high school senior with a promising swimming...
#
#        num_criticas_publico  num_criticas_critica
# 4                     142.0                  62.0
# 11                    502.0                 161.0
# 21                    125.0                  72.0
# 22                     45.0                  74.0
# 25                     17.0                   5.0
# ...                     ...                   ...
# 28435                 105.0                  33.0
# 28455                 115.0                  49.0
# 28480                 519.0                 427.0
# 28485                 940.0                 241.0
# 28489                 216.0                  88.0
#
# [2584 rows x 20 columns]

# %%
imdb.query("ano <= 1980").plot("receita", "orcamento", kind = "scatter")
